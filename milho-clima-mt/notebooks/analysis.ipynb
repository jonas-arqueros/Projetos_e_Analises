# %%
# 🌽 Análise do Impacto do Clima na Produção de Milho - Mato Grosso

## 1. Importação de Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Estilo dos gráficos
sns.set(style="whitegrid") 
# %matplotlib inline

# %%
## 2. Carregamento dos Dados

# Substituir pelos arquivos reais assim que baixar
df_producao = pd.read_csv("C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/milho-mt.csv", sep = ";", quotechar='"', skiprows=3)
df_clima = pd.read_csv("C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/dados_clima_mt.csv", sep = ",", quotechar='"')

# Visualizar as primeiras linhas
display(df_producao.head(10))
display(df_clima.head())
# Out:
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_14116\1329663467.py:5: DtypeWarning: Columns (1,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_clima = pd.read_csv("C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/dados_clima_mt.csv", sep = ",", quotechar='"')
#          Nível                                               Cód.  \
# Nível     Cód.  UF, Mesorregião, Microrregião e Município, em ...
# UF          51                                        Mato Grosso
# ME        5101                               Norte Mato-grossense
# MI       51001                                           Aripuanã
# MU     5101407                                           Aripuanã
# MU     5101902                                          Brasnorte
# MU     5102850                                        Castanheira
# MU     5103254                                            Colniza
# ...
