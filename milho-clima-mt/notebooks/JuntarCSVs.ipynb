# %%
import pandas as pd
from glob import glob
import os

caminho_pasta = r"C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs"
arquivos = glob(os.path.join(caminho_pasta, "*.csv"))

lista_df = []

for arquivo in arquivos:
    try:
        df = pd.read_csv(arquivo, sep=";", encoding="latin1",skiprows=10)

        # Padroniza os nomes das colunas
        df.columns = [col.lower()
                          .strip()
                          .replace(" ", "_")
                          .replace(",", "")
                          .replace("(", "")
                          .replace(")", "")
                          .replace("ã", "a")
                          .replace("á", "a")
                          .replace("é", "e")
                          .replace("í", "i")
                          .replace("ó", "o")
                          .replace("ú", "u")
                          .replace("ç", "c")
                          .replace("°", "")
                          for col in df.columns]

                # Faz o rename baseado em parte do nome (mais tolerante a variações)
        colunas_renomeadas = {}
        for col in df.columns:
            if "data" in col:
                colunas_renomeadas[col] = "data"
            elif "precipitacao" in col:
                colunas_renomeadas[col] = "precipitacao"
            elif "temperatura_maxima" in col:
                colunas_renomeadas[col] = "temp_max"
            elif "temperatura_minima" in col:
                colunas_renomeadas[col] = "temp_min"
            elif "temperatura_media" in col or "temperatura_compensada" in col:
                colunas_renomeadas[col] = "temp_med"
            elif "umidade_relativa" in col and "media" in col:
                colunas_renomeadas[col] = "umid_med"
            elif "umidade_relativa" in col and "minima" in col:
                colunas_renomeadas[col] = "umid_min"

        df = df.rename(columns=colunas_renomeadas)

        # Adiciona a estação
        df["estacao"] = os.path.basename(arquivo).split("_")[1]

        # Seleciona colunas úteis
        colunas_finais = ["data", "estacao", "precipitacao", "temp_min", "temp_med", "temp_max", "umid_min", "umid_med"]
        df = df[[col for col in colunas_finais if col in df.columns]]

        # Mostra colunas do arquivo atual
        print(f"📁 {arquivo}")
        print("✅ Colunas reconhecidas:", df.columns.tolist())
        print("-" * 40)

        lista_df.append(df)

    except Exception as e:
        print(f"Erro no arquivo {arquivo}: {e}")

# Junta tudo
if lista_df:
    df_clima = pd.concat(lista_df, ignore_index=True)
    print("🎉 Dados finais unidos!")
    print(df_clima.head())
else:
    print("❌ Nenhum dado válido foi encontrado.")
# Out:
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_82927_D_2000-01-01_2000-11-07.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83214_D_2000-01-01_2021-03-14.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83264_D_2000-01-01_2014-05-01.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83265_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83267_D_2000-01-01_2016-01-29.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83270_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83309_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83319_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83358_D_2000-01-01_2021-07-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83361_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83363_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83364_D_2000-01-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83367_D_2000-01-01_2002-11-24.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83405_D_2000-01-01_2014-07-02.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_83410_D_2000-01-01_2016-01-28.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A901_D_2002-12-07_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A902_D_2002-12-10_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A903_D_2003-02-24_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A904_D_2002-12-15_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A905_D_2002-12-12_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A906_D_2002-12-19_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A907_D_2003-11-16_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A908_D_2006-12-15_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A909_D_2011-09-21_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A910_D_2006-10-23_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A911_D_2017-10-19_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A912_D_2006-11-20_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A913_D_2006-11-27_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A914_D_2006-11-01_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A915_D_2006-12-18_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A916_D_2007-07-17_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A917_D_2006-10-28_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A918_D_2008-06-06_2018-03-11.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A919_D_2007-05-27_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A920_D_2006-11-23_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A921_D_2007-10-18_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A922_D_2006-11-30_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A923_D_2017-10-25_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A924_D_2007-05-22_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A926_D_2008-04-08_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A927_D_2008-02-28_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A928_D_2008-04-15_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A929_D_2008-04-12_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A930_D_2008-06-03_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A931_D_2008-05-29_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A932_D_2008-01-23_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A933_D_2008-08-13_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A934_D_2008-01-28_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A935_D_2008-05-29_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A936_D_2008-01-23_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A937_D_2008-01-29_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A941_D_2012-03-29_2021-01-07.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A942_D_2019-02-18_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A943_D_2019-03-28_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 📁 C:/Users/Jonas/Documents/MeusProjetos/Projetos_e_Analises/milho-clima-mt/data/raw/inmet_csvs\dados_A944_D_2019-05-29_2023-12-31.csv
# ✅ Colunas reconhecidas: ['data', 'estacao', 'precipitacao', 'temp_min', 'temp_med', 'temp_max', 'umid_min', 'umid_med']
# ----------------------------------------
# 🎉 Dados finais unidos!
#          data estacao precipitacao temp_min temp_med temp_max umid_min  \
# 0  2000-01-01   82927          NaN       21     25,5       32     69.0
# 1  2000-01-02   82927          NaN     22,6      NaN      NaN     67.0
# 2  2000-01-03   82927          NaN       22     25,8       33     79.0
# 3  2000-01-04   82927          NaN     22,4     25,5     33,2     74.0
# 4  2000-01-05   82927          NaN       25      NaN     28,8     90.0
#
#   umid_med
# 0     84,3
# 1      NaN
# 2     89,3
# 3     86,8
# 4      NaN

# %%
df_clima
# Out:
#               data estacao precipitacao temp_min temp_med temp_max umid_min  \
# 0       2000-01-01   82927          NaN       21     25,5       32     69.0
# 1       2000-01-02   82927          NaN     22,6      NaN      NaN     67.0
# 2       2000-01-03   82927          NaN       22     25,8       33     79.0
# 3       2000-01-04   82927          NaN     22,4     25,5     33,2     74.0
# 4       2000-01-05   82927          NaN       25      NaN     28,8     90.0
# ...            ...     ...          ...      ...      ...      ...      ...
# 324331  2023-12-27    A944          NaN     21,8      NaN     35,7     39.0
# 324332  2023-12-28    A944          NaN     22,8      NaN     38,3     31.0
# 324333  2023-12-29    A944          NaN     24,9      NaN     34,3     51.0
# 324334  2023-12-30    A944          NaN     22,9      NaN     33,7     48.0
# 324335  2023-12-31    A944            0     22,6       27     32,6     51.0
#
#        umid_med
# 0          84,3
# 1           NaN
# 2          89,3
# 3          86,8
# 4           NaN
# ...         ...
# 324331     72,2
# 324332     65,5
# 324333     79,3
# 324334     79,1
# 324335     77,6
#
# [324336 rows x 8 columns]

# %%
df_clima.to_csv("dados_clima_mt.csv", index=False, encoding="utf-8")
